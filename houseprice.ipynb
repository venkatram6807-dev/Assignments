# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": null,
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "TH9Hw7-cTval",
        "outputId": "0b6fa087-fc90-4a12-b674-429879731327"
      },
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "      Id  MSSubClass  LotArea Neighborhood  OverallQual  OverallCond  \\\n",
            "0      1          30    11325        NAmes            5            2   \n",
            "1      2          30     3537      Edwards            1            7   \n",
            "2      3          30    11685        NAmes            6            1   \n",
            "3      4          30     8915        NAmes            9            4   \n",
            "4      5          30    14467      Edwards            5            1   \n",
            "..   ...         ...      ...          ...          ...          ...   \n",
            "195  196          60     5810        NAmes            3            9   \n",
            "196  197          70     3215      CollgCr            7            4   \n",
            "197  198          70     8215      CollgCr           10            3   \n",
            "198  199          60     9278      Edwards            3            3   \n",
            "199  200          70     7203      Somerst            2           10   \n",
            "\n",
            "     YearBuilt HouseStyle  GrLivArea  BedroomAbvGr  GarageCars  SalePrice  \n",
            "0         2013     2Story     2434.0             6           3     463518  \n",
            "1         2005     1.5Fin     3622.0             1           3     189633  \n",
            "2         1952     1Story     3160.0             5           0     249860  \n",
            "3         2006     2Story     2764.0             2           2     171040  \n",
            "4         2003     1.5Fin     3130.0             1           1     379962  \n",
            "..         ...        ...        ...           ...         ...        ...  \n",
            "195       1996     2Story     1703.0             4           3     325986  \n",
            "196       1955     1.5Fin     1486.0             6           1     177661  \n",
            "197       1988     1.5Fin     3444.0             3           0     423642  \n",
            "198       1953     2Story     2289.0             5           2     470055  \n",
            "199       1987     1.5Fin     3214.0             3           3      55920  \n",
            "\n",
            "[200 rows x 12 columns]\n"
          ]
        }
      ],
      "source": [
        "import pandas as pd\n",
        "\n",
        "df = pd.read_csv(\"train.csv\")\n",
        "print(df)\n"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(\"\\nFirst 10 Rows:\")\n",
        "print(df.head(10))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "Na0_c_OrUUsQ",
        "outputId": "3423d515-b135-4b38-d29a-5100c9ce3f46"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "\n",
            "First 10 Rows:\n",
            "   Id  MSSubClass  LotArea Neighborhood  OverallQual  OverallCond  YearBuilt  \\\n",
            "0   1          30    11325        NAmes            5            2       2013   \n",
            "1   2          30     3537      Edwards            1            7       2005   \n",
            "2   3          30    11685        NAmes            6            1       1952   \n",
            "3   4          30     8915        NAmes            9            4       2006   \n",
            "4   5          30    14467      Edwards            5            1       2003   \n",
            "5   6          60     3980      OldTown            9            7       2014   \n",
            "6   7          70    10278      Edwards           10            1       2011   \n",
            "7   8          30     8014      Somerst            6            2       2006   \n",
            "8   9          70     8070      Edwards            1            8       1955   \n",
            "9  10          70    12603      CollgCr            3            9       1979   \n",
            "\n",
            "  HouseStyle  GrLivArea  BedroomAbvGr  GarageCars  SalePrice  \n",
            "0     2Story     2434.0             6           3     463518  \n",
            "1     1.5Fin     3622.0             1           3     189633  \n",
            "2     1Story     3160.0             5           0     249860  \n",
            "3     2Story     2764.0             2           2     171040  \n",
            "4     1.5Fin     3130.0             1           1     379962  \n",
            "5     1.5Fin     1277.0             3           2     358061  \n",
            "6     1Story     3546.0             4           3     398517  \n",
            "7     1.5Fin     2582.0             1           1     323121  \n",
            "8     2Story     3381.0             5           4     353130  \n",
            "9     1Story     3656.0             2           4     337487  \n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.tail(10))"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "pOLcwmY2U-uk",
        "outputId": "d4b0cb87-f56e-425a-b0a6-3556839339b6"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "      Id  MSSubClass  LotArea Neighborhood  OverallQual  OverallCond  \\\n",
            "190  191          70    11891      Edwards            3            5   \n",
            "191  192          60     6184          NaN            1           10   \n",
            "192  193          70     5426          NaN            6            3   \n",
            "193  194          20     6191      Somerst            1            5   \n",
            "194  195          20     5417        NAmes            6            2   \n",
            "195  196          60     5810        NAmes            3            9   \n",
            "196  197          70     3215      CollgCr            7            4   \n",
            "197  198          70     8215      CollgCr           10            3   \n",
            "198  199          60     9278      Edwards            3            3   \n",
            "199  200          70     7203      Somerst            2           10   \n",
            "\n",
            "     YearBuilt HouseStyle  GrLivArea  BedroomAbvGr  GarageCars  SalePrice  \n",
            "190       2017     2Story     2807.0             4           4     332963  \n",
            "191       1955     2Story        NaN             3           1     316330  \n",
            "192       1999     2Story      722.0             6           0     236814  \n",
            "193       1998     1Story     1829.0             3           2     358903  \n",
            "194       1958     1Story     3699.0             6           2     264780  \n",
            "195       1996     2Story     1703.0             4           3     325986  \n",
            "196       1955     1.5Fin     1486.0             6           1     177661  \n",
            "197       1988     1.5Fin     3444.0             3           0     423642  \n",
            "198       1953     2Story     2289.0             5           2     470055  \n",
            "199       1987     1.5Fin     3214.0             3           3      55920  \n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.shape)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "REiGIJHwVBuo",
        "outputId": "5506fc00-683e-4d51-f111-193271fbe7aa"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "(200, 12)\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(\"\\nColumn Names:\")\n",
        "print(df.columns)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "yJwxTeWxVERL",
        "outputId": "3ab471ed-a756-448f-9b68-57c76d1c41c2"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "\n",
            "Column Names:\n",
            "Index(['Id', 'MSSubClass', 'LotArea', 'Neighborhood', 'OverallQual',\n",
            "       'OverallCond', 'YearBuilt', 'HouseStyle', 'GrLivArea', 'BedroomAbvGr',\n",
            "       'GarageCars', 'SalePrice'],\n",
            "      dtype='object')\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.dtypes)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "_gGPLaktVGbl",
        "outputId": "177aea87-1904-4da3-ffd3-b118dfbff33b"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Id                int64\n",
            "MSSubClass        int64\n",
            "LotArea           int64\n",
            "Neighborhood     object\n",
            "OverallQual       int64\n",
            "OverallCond       int64\n",
            "YearBuilt         int64\n",
            "HouseStyle       object\n",
            "GrLivArea       float64\n",
            "BedroomAbvGr      int64\n",
            "GarageCars        int64\n",
            "SalePrice         int64\n",
            "dtype: object\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df.info()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "b0bF1Pe7VI4b",
        "outputId": "180e1997-c2eb-433f-e874-ec9d1b69dca0"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "<class 'pandas.core.frame.DataFrame'>\n",
            "RangeIndex: 200 entries, 0 to 199\n",
            "Data columns (total 12 columns):\n",
            " #   Column        Non-Null Count  Dtype  \n",
            "---  ------        --------------  -----  \n",
            " 0   Id            200 non-null    int64  \n",
            " 1   MSSubClass    200 non-null    int64  \n",
            " 2   LotArea       200 non-null    int64  \n",
            " 3   Neighborhood  190 non-null    object \n",
            " 4   OverallQual   200 non-null    int64  \n",
            " 5   OverallCond   200 non-null    int64  \n",
            " 6   YearBuilt     200 non-null    int64  \n",
            " 7   HouseStyle    200 non-null    object \n",
            " 8   GrLivArea     190 non-null    float64\n",
            " 9   BedroomAbvGr  200 non-null    int64  \n",
            " 10  GarageCars    200 non-null    int64  \n",
            " 11  SalePrice     200 non-null    int64  \n",
            "dtypes: float64(1), int64(9), object(2)\n",
            "memory usage: 18.9+ KB\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.describe())\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "Zi7lZRRzVLoZ",
        "outputId": "5c00e2cd-c521-4ece-f9dd-8b0e40ce7409"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "               Id  MSSubClass       LotArea  OverallQual  OverallCond  \\\n",
            "count  200.000000  200.000000    200.000000   200.000000   200.000000   \n",
            "mean   100.500000   46.000000   8046.850000     5.700000     5.335000   \n",
            "std     57.879185   19.848674   3628.766915     2.936514     3.012999   \n",
            "min      1.000000   20.000000   2013.000000     1.000000     1.000000   \n",
            "25%     50.750000   30.000000   4918.000000     3.000000     3.000000   \n",
            "50%    100.500000   60.000000   8047.500000     6.000000     5.000000   \n",
            "75%    150.250000   60.000000  11390.250000     8.000000     8.000000   \n",
            "max    200.000000   70.000000  14891.000000    10.000000    10.000000   \n",
            "\n",
            "         YearBuilt    GrLivArea  BedroomAbvGr  GarageCars      SalePrice  \n",
            "count   200.000000   190.000000     200.00000  200.000000     200.000000  \n",
            "mean   1985.150000  2389.089474       3.59500    2.100000  283385.915000  \n",
            "std      21.229246   992.762442       1.60745    1.459676  128665.406668  \n",
            "min    1950.000000   506.000000       1.00000    0.000000   55697.000000  \n",
            "25%    1967.000000  1603.750000       2.00000    1.000000  173477.000000  \n",
            "50%    1984.500000  2467.500000       3.00000    2.000000  300837.000000  \n",
            "75%    2004.000000  3207.250000       5.00000    3.000000  386770.250000  \n",
            "max    2019.000000  4000.000000       6.00000    4.000000  499399.000000  \n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.duplicated().sum())"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "kEGUbTDmVOXH",
        "outputId": "b4bba265-023f-467a-f07d-7d3ce3f743f2"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "0\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.isnull().sum())\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "cibC4dCcVRDH",
        "outputId": "7ca37c37-f84b-4e79-c8bb-d1d6bdefd368"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Id               0\n",
            "MSSubClass       0\n",
            "LotArea          0\n",
            "Neighborhood    10\n",
            "OverallQual      0\n",
            "OverallCond      0\n",
            "YearBuilt        0\n",
            "HouseStyle       0\n",
            "GrLivArea       10\n",
            "BedroomAbvGr     0\n",
            "GarageCars       0\n",
            "SalePrice        0\n",
            "dtype: int64\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.isnull().sum().sum())"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "BhzAHgrRVVuW",
        "outputId": "1db8137f-3dff-4380-db9d-2a131fed07ea"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "20\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.isnull().sum()[df.isnull().sum() > 0])"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "6aMBHau1VYlZ",
        "outputId": "e50486e4-027a-442b-bf5a-f8838bb9658e"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Neighborhood    10\n",
            "GrLivArea       10\n",
            "dtype: int64\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print((df.isnull().sum() / len(df)) * 100)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "r7bCSPrDWNoP",
        "outputId": "8bf968e4-85d3-4c3c-da27-610726b1b871"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Id              0.0\n",
            "MSSubClass      0.0\n",
            "LotArea         0.0\n",
            "Neighborhood    5.0\n",
            "OverallQual     0.0\n",
            "OverallCond     0.0\n",
            "YearBuilt       0.0\n",
            "HouseStyle      0.0\n",
            "GrLivArea       5.0\n",
            "BedroomAbvGr    0.0\n",
            "GarageCars      0.0\n",
            "SalePrice       0.0\n",
            "dtype: float64\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "print(df.isnull().sum().idxmax())\n",
        "print(\"Missing Values:\", df.isnull().sum().max())"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "FcpZNNTNWQee",
        "outputId": "ac43e874-7d1f-4db0-af58-65ff44a31500"
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Neighborhood\n",
            "Missing Values: 10\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df[\"Neighborhood\"] = df[\"Neighborhood\"].fillna(df[\"Neighborhood\"].mode()[0])"
      ],
      "metadata": {
        "id": "M57qtOQTWrQf"
      },
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "df[\"LotArea\"] = df[\"LotArea\"].fillna(df[\"LotArea\"].median())"
      ],
      "metadata": {
        "id": "9ZZDGdOEazUa"
      },
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "df[\"OverallQual\"] = df[\"OverallQual\"].fillna(df[\"OverallQual\"].median())"
      ],
      "metadata": {
        "id": "hTaZyZu8a3n4"
      },
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "df[\"OverallCond\"] = df[\"OverallCond\"].fillna(df[\"OverallCond\"].median())"
      ],
      "metadata": {
        "id": "fvLotXxMa5g3"
      },
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "df[\"HouseStyle\"] = df[\"HouseStyle\"].fillna(df[\"HouseStyle\"].mode()[0])"
      ],
      "metadata": {
        "id": "TFulCIJ8a7UR"
      },
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "df[\"GarageCars\"] = df[\"GarageCars\"].fillna(0)"
      ],
      "metadata": {
        "id": "R-Kf80FIbBcc"
      },
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "threshold = len(df) * 0.5\n",
        "df = df.dropna(axis=1, thresh=threshold)\n",
        "\n",
        "print(\"Updated Dataset Information:\")\n",
        "df.info()"
      ],
      "metadata": {
        "id": "11yZx1LHbD3i",
        "outputId": "3ad37be2-5961-4399-9877-cdbdea3f0878",
        "colab": {
          "base_uri": "https://localhost:8080/"
        }
      },
      "execution_count": null,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stdout",
          "text": [
            "Updated Dataset Information:\n",
            "<class 'pandas.core.frame.DataFrame'>\n",
            "RangeIndex: 200 entries, 0 to 199\n",
            "Data columns (total 12 columns):\n",
            " #   Column        Non-Null Count  Dtype  \n",
            "---  ------        --------------  -----  \n",
            " 0   Id            200 non-null    int64  \n",
            " 1   MSSubClass    200 non-null    int64  \n",
            " 2   LotArea       200 non-null    int64  \n",
            " 3   Neighborhood  200 non-null    object \n",
            " 4   OverallQual   200 non-null    int64  \n",
            " 5   OverallCond   200 non-null    int64  \n",
            " 6   YearBuilt     200 non-null    int64  \n",
            " 7   HouseStyle    200 non-null    object \n",
            " 8   GrLivArea     190 non-null    float64\n",
            " 9   BedroomAbvGr  200 non-null    int64  \n",
            " 10  GarageCars    200 non-null    int64  \n",
            " 11  SalePrice     200 non-null    int64  \n",
            "dtypes: float64(1), int64(9), object(2)\n",
            "memory usage: 18.9+ KB\n"
          ]
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [],
      "metadata": {
        "id": "upUAkBVibFr2"
      },
      "execution_count": null,
      "outputs": []
    }
  ]
}
